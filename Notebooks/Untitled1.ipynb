# %%
import json
import os
from collections import defaultdict
import string 
import nltk
from collections import Counter
import math
import re

from estnltk.taggers import VabamorfTagger
from estnltk import Span, Layer
from estnltk.tests import new_text
from estnltk.converters import text_to_json, json_to_text

# %%
with open("../Loendid/tajuverbid/wordnet_tajuverbid.txt", "r", encoding = "utf8") as fr:
    lines = fr.readlines()
    tajuverbid = [verb.strip() for verb in lines]

# %%
tajuverbid
# Out:
# ['aimuma',
#  'aistima',
#  'avastama',
#  'avasui',
#  'fikseerima',
#  'haiget',
#  'haistma',
#  'hakkama',
#  'heitma',
#  'hoomama',
#  'hõõguma',
#  'janu',
#  'janune',
#  'janunema',
#  'jälgima',
#  'jõllitama',
#  'kaema',
#  'kannatama',
#  'kartma',
#  'kihelema',
#  'kiikama',
#  'kiinduma',
#  'kipitama',
#  'kissitama',
#  'kuivama',
#  'kummastama',
#  'kuulama',
#  'kuulatama',
#  'kuulma',
#  'kuumama',
#  'käima',
#  'kõrbema',
#  'kõõrdi',
#  'kõõritama',
#  'kõõrutama',
#  'külma',
#  'külmetama',
#  'leidma',
#  'luurama',
#  'läbi',
#  'maitset',
#  'maitsma',
#  'molukil',
#  'molutama',
#  'märkama',
#  'nuhutama',
#  'nuuskima',
#  'nuusutama',
#  'nägema',
#  'nälga',
#  'nälgima',
#  'pakitama',
#  'pakitsema',
#  'panema',
#  'peale',
#  'pealt',
#  'peegeldama',
#  'peegelduma',
#  'pelgama',
#  'piidlema',
#  'piiluma',
#  'piinlema',
#  'pilku',
#  'pilutama',
#  'pungitama',
#  'puurima',
#  'puutuma',
#  'põrnitsema',
#  'põrutama',
#  'ringi',
#  'saama',
#  'saatma',
#  'sattuma',
#  'sedastama',
#  'seirama',
#  'seletama',
#  'silma',
#  'silmama',
#  'silmitsema',
#  'sirvima',
#  'särama',
#  'sügelema',
#  'tajuma',
#  'takseerima',
#  'tegema',
#  'torkama',
#  'tuigatama',
#  'tuikama',
#  'tulitama',
#  'tundma',
#  'tunnistama',
#  'täheldama',
#  'tähele',
#  'uudistama',
#  'vaatama',
#  'vaatlema',
#  'vahtima',
#  'valutama',
#  'vastu',
#  'vidutama',
#  'vigastuma',
#  'vilksama',
#  'vilutama',
#  'visiteerima',
#  'volksama',
#  'volksatama',
#  'võtma']

# %%
# Algse kausta nimi, võtab sealt algsed failinimed, ei loe neid faile sisse
source = "../etnc19_web_2019_100000/"

os.makedirs(os.path.dirname("../etnc19_web_2019_andmed/"), exist_ok=True)

with open("keskmised.json", "r", encoding = "UTF-8") as fr:
    keskmised = json.load(fr)

# %%
for filename in [f for f in os.listdir(source)]:
    
    ga_name = os.path.join("../etnc19_web_2019_morf_oletamisega/", ".".join(filename.split(".")[:-1]) + "_morf_oletamisega.json")
    
    oletamisega = json_to_text(file=ga_name)
    
    all_verbs = 0
    only_tajuverbs = 0

    for lemma, postag in zip(oletamisega.lemma, oletamisega.partofspeech):
        if "V" in postag:
            all_verbs += 1
            for lemmake in lemma:
                if lemmake in tajuverbid:
# Out:
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-5018bd1b1b74> in <module>()
#      13             for lemmake in lemma:
#      14                 if lemmake in tajuverbid:
# ---> 15                     print("a")
#
# C:\Users\kusti\anaconda3\envs\maka\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# C:\Users\kusti\anaconda3\envs\maka\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# C:\Users\kusti\anaconda3\envs\maka\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     539                 )
#     540             data.group = group
# --> 541         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     542
#     543     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# C:\Users\kusti\anaconda3\envs\maka\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
lemmas_subwords
# Out:
# ['oi',
#  'jeebus',
#  '.',
#  'hetk',
#  'kakle',
#  'deemon',
#  'mina',
#  'vaim',
#  'ja',
#  'keha',
#  'pärast',
#  '.',
#  'üks',
#  'tema',
#  'suru',
#  'peale',
#  'egoism',
#  'ja',
#  'teine',
#  'võitle',
#  'järele',
#  'andmatult',
#  'mina',
#  'inimlik',
#  'pool',
#  'eest',
#  '.',
#  'üks',
#  'tema',
#  'ole',
#  'nõus',
#  'pea',
#  'raju',
#  'vana',
#  'traditsiooniline',
#  'mõte',
#  'eest',
#  ',',
#  'teine',
#  'purska',
#  'vihaselt',
#  'tuli',
#  'uuendus',
#  'pärast',
#  '.',
#  'ees',
#  'märk',
#  ',',
#  'mis',
#  'pärat',
#  'areen',
#  'mine',
#  ',',
#  'vahetu',
#  'pidevalt',
#  '.',
#  'ei',
#  'tead',
#  'kumb',
#  'tema',
#  'võit',
#  ',',
#  'mõlema',
#  'sans',
#  'ole',
#  'suure',
#  'pärane',
#  '.',
#  'mina',
#  'tead',
#  ',',
#  'et',
#  'tema',
#  'lõpeta',
#  'kunagi',
#  ',',
#  'kui',
#  'tema',
#  'väsi',
#  'ole',
#  'ja',
#  'asi',
#  'kulmineeru',
#  'see',
#  'korraks',
#  '.',
#  'kuid',
#  'tulevik',
#  ',',
#  'nagu',
#  'ka',
#  'minevik',
#  ',',
#  'ette',
#  'hoiatamata',
#  'aja',
#  'tema',
#  'oma',
#  'raud',
#  'kuum',
#  'ja',
#  'kõik',
#  'alga',
#  'uuesti',
#  '.',
#  'mina',
#  'ei',
#  'püüd',
#  'see',
#  'enam',
#  'takista',
#  ',',
#  'peata',
#  ',',
#  'lepita',
#  'tema',
#  'vahe',
#  'rahu',
#  ',',
#  'kuna',
#  'mina',
#  'tead',
#  ',',
#  'et',
#  'see',
#  'tootlik',
#  'puudu',
#  'ja',
#  'see',
#  'ole',
#  'kasutu',
#  '.',
#  'mina',
#  'ei',
#  'saavuta',
#  'oma',
#  'lõpp',
#  'ees',
#  'märk',
#  '.',
#  'mina',
#  'lask',
#  'tema',
#  'rahu',
#  'verista',
#  'ja',
#  'kõndi',
#  'oma',
#  'tee',
#  '.',
#  'see',
#  'tõttu',
#  'ei',
#  'ilmu',
#  'täna',
#  'siia',
#  'blogi',
#  'miski',
#  'peale',
#  'haigutav',
#  'tühjus',
#  '.',
#  'peale',
#  'tunne',
#  ',',
#  'kooli',
#  'päev',
#  'lõppe',
#  'või',
#  'üks',
#  'september',
#  'õhtu',
#  'leid',
#  'Viljar',
#  'arvuti',
#  'klass',
#  '.',
#  'tema',
#  'ei',
#  'olnud',
#  'seal',
#  '"',
#  'peale',
#  'tund',
#  '"',
#  'jäämine',
#  'põhjus',
#  'vaid',
#  'viimane',
#  'aeg',
#  'leid',
#  'tema',
#  ',',
#  'et',
#  'kool',
#  'arvuti',
#  'klass',
#  'kasutamine',
#  'võimalus',
#  'ole',
#  'nagu',
#  'jumal',
#  'poolt',
#  'kingitus',
#  '.',
#  'kodu',
#  'tema',
#  'veel',
#  'oma',
#  'arvuti',
#  'ei',
#  'olnud',
#  'ning',
#  'kool',
#  'ole',
#  'peale',
#  'tunne',
#  'luba',
#  'raali',
#  'ruum',
#  'kasuta',
#  ',',
#  'eriti',
#  'siis',
#  'kui',
#  'sina',
#  'eri',
#  'ala',
#  'ole',
#  'veel',
#  'IT',
#  '.',
#  'Jutuka',
#  'istu',
#  'avasta',
#  'Viljar',
#  ',',
#  'et',
#  'peale',
#  'tema',
#  'ole',
#  'veel',
#  'ruum',
#  'üks',
#  'inimene',
#  'ning',
#  'tema',
#  'mõtle',
#  ',',
#  'et',
#  'ju',
#  'siis',
#  'prill',
#  'kandev',
#  'noor',
#  'mees',
#  'ole',
#  'sama',
#  'põhjus',
#  ',',
#  'tege',
#  'aeg',
#  'paras',
#  'enne',
#  'kodu',
#  'minek',
#  '.',
#  'see',
#  'tema',
#  'küsi',
#  'ei',
#  'hakanud',
#  ',',
#  'kuna',
#  'filx',
#  'ei',
#  'pida',
#  'see',
#  'vajalik',
#  'ja',
#  'pealegi',
#  'ole',
#  'tema',
#  'moodi',
#  'mine',
#  'võhivöörane',
#  'inimene',
#  'juurde',
#  'ja',
#  'õelda',
#  '"',
#  'Sup',
#  ',',
#  'mina',
#  'ole',
#  'filx',
#  '"',
#  '.',
#  'ei',
#  'läinud',
#  'palju',
#  'aeg',
#  'mõõt',
#  ',',
#  'kui',
#  'kaugemal',
#  'olev',
#  'tüüp',
#  'oma',
#  'tegevus',
#  'korraks',
#  'katesta',
#  'ning',
#  'kõneta',
#  'IRC',
#  'süvene',
#  'Viljar',
#  ':',
#  '"',
#  'Jou',
#  ',',
#  'oska',
#  'sina',
#  'mõni',
#  'hea',
#  'lugu',
#  'soovita',
#  '"',
#  '.',
#  'see',
#  'tule',
#  'filx',
#  'jaoks',
#  'suht',
#  'üllatus',
#  '.',
#  'tema',
#  'lõpeta',
#  'hetk',
#  'arvuti',
#  'ekraan',
#  'jälgmise',
#  'ning',
#  'nagu',
#  'mall',
#  'järgi',
#  'vasta',
#  ':',
#  '"',
#  'ei',
#  'tead',
#  '"',
#  '.',
#  'mõni',
#  'hetk',
#  'hiljem',
#  'meenu',
#  'tema',
#  ',',
#  'et',
#  'ole',
#  'raadio',
#  'kuul',
#  'üks',
#  'hea',
#  'lugu',
#  '-',
#  'Noemi',
#  'Y',
#  '.',
#  'O',
#  '.',
#  'U',
#  'ning',
#  'and',
#  'see',
#  'tead',
#  '.',
#  'hiljem',
#  'vestlus',
#  'arende',
#  'hakka',
#  'filxi',
#  'kummi',
#  ',',
#  'et',
#  'huvitav',
#  ',',
#  'kas',
#  'muusika',
#  'tõmbamine',
#  'ole',
#  'mitte',
#  'keela',
#  'tegevus',
#  'nime',
#  'kiri',
#  '.',
#  'jah',
#  ',',
#  'reegel',
#  'ole',
#  'ju',
#  'ainult',
#  'see',
#  ',',
#  'et',
#  'tema',
#  'kõrvale',
#  'hiili',
#  '.',
#  'kui',
#  'tema',
#  'küsi',
#  'siiski',
#  ',',
#  '"',
#  'kas',
#  'Kazaa',
#  'kasutamine',
#  'ole',
#  'mitte',
#  'keela',
#  '"',
#  '.',
#  'ning',
#  'tema',
#  'saa',
#  'vastus',
#  ',',
#  'et',
#  'kui',
#  'teine',
#  'ei',
#  'sega',
#  'siis',
#  'või',
#  '.',
#  'rong',
#  'sõit',
#  ',',
#  'suur',
#  'igavus',
#  'külasta',
#  'tv',
#  'seriaal',
#  'kajastav',
#  'leht',
#  'www.tv.com',
#  'ning',
#  'ise',
#  'üllatus',
#  'avasta',
#  ',',
#  'et',
#  'BSG',
#  'alusta',
#  'juba',
#  'järgmine',
#  'reede',
#  '(',
#  '5.',
#  'okt',
#  '2007',
#  ')',
#  'kümme',
#  'osaline',
#  'mini',
#  'episood',
#  'sari',
#  '.',
#  'ekraan',
#  'jõudev',
#  'osa',
#  'ise',
#  'enesest',
#  'ole',
#  'väga',
#  'lühike',
#  ',',
#  '2',
#  '-',
#  '3',
#  'kolm',
#  'minut',
#  'pikkune',
#  'ja',
#  'rääki',
#  'noor',
#  'piloot',
#  'William',
#  '"',
#  'Husker',
#  '"',
#  'Adama',
#  '.',
#  'ehk',
#  'siis',
#  'vaataja',
#  'jõud',
#  'kümme',
#  'osaline',
#  'lugu',
#  'noor',
#  'admiral',
#  'Adama',
#  ',',
#  'kes',
#  'esimene',
#  'Cylon',
#  'sõda',
#  'aeg',
#  'avasta',
#  'Cylon',
#  'relv',
#  '.',
#  'Õnneks',
#  'ole',
#  'SciFi',
#  'kanal',
#  'mees',
#  'välja',
#  'jaga',
#  ',',
#  'et',
#  'mina',
#  'Eesti',
#  'TV3',
#  'ei',
#  'taht',
#  'uus',
#  'näita',
#  'ja',
#  'nõnda',
#  'tema',
#  'pane',
#  'see',
#  'mini',
#  'osa',
#  'ka',
#  'oma',
#  'veeb',
#  'üles',
#  '.',
#  'detsember',
#  ',',
#  'täpsemalt',
#  '11.',
#  'kuu',
#  'päev',
#  'või',
#  'näge',
#  'juba',
#  'täis',
#  'pikk',
#  'film',
#  'nimi',
#  '"',
#  'Razor',
#  '"',
#  ',',
#  'mis',
#  'jutusta',
#  'mina',
#  'lood',
#  'uus',
#  'tegelane',
#  'Kendra',
#  'Shaw',
#  '.',
#  'kuri',
#  'keel',
#  'pajata',
#  ',',
#  'et',
#  'tegemine',
#  'ole',
#  'ette',
#  'arvamatu',
#  'pegasus',
#  'ohvitser',
#  '.',
#  'siin',
#  'saa',
#  'treiler',
#  'vaata',
#  '.',
#  'see',
#  ',',
#  'kes',
#  'ole',
#  'õrn',
#  'aim',
#  ',',
#  'mis',
#  'see',
#  'Battlestar',
#  'Galactica',
#  'ole',
#  'ja',
#  'taht',
#  'kangesti',
#  'tead',
#  '(',
#  'mina',
#  'tead',
#  ',',
#  'et',
#  'sina',
#  'taht',
#  ')',
#  'siis',
#  'soovita',
#  'tutvustus',
#  'vaata',
#  'see',
#  ':',
#  'The',
#  'Story',
#  'So',
#  'Far',
#  'nagu',
#  'peal',
#  'kiri',
#  'pihta',
#  'saa',
#  'siis',
#  'täna',
#  'ole',
#  'hea',
#  'päev',
#  '.',
#  'vähemalt',
#  'mina',
#  '.',
#  'tegelikult',
#  'ole',
#  'iga',
#  'päev',
#  'hea',
#  ',',
#  'kui',
#  'vaata',
#  'asi',
#  'õige',
#  'valgus',
#  '.',
#  'mõni',
#  'teadlane',
#  'poolt',
#  'uuri',
#  'ja',
#  'kinnita',
#  'argument',
#  ',',
#  'miks',
#  'täna',
#  'hea',
#  'päev',
#  'ole',
#  ':',
#  'jess',
#  ',',
#  'palga',
#  'päev',
#  '.',
#  'mina',
#  'mine',
#  'hommik',
#  'loll',
#  'ja',
#  'kontuktor',
#  'ole',
#  'andu',
#  'vastu',
#  'hammas',
#  'trolli',
#  '.',
#  'peale',
#  'nädalane',
#  'hool',
#  'õppimine',
#  'ja',
#  'praktiseerimine',
#  'saa',
#  'täna',
#  'värviline',
#  'ja',
#  'tähtis',
#  'paber',
#  ',',
#  'mis',
#  'tunnista',
#  'mina',
#  'meditsiin',
#  'oskus',
#  '.',
#  'XP',
#  'tõus',
#  'ikka',
#  'oma',
#  'jagu',
#  '.',
#  'käi',
#  'poodle',
#  'ja',
#  'see',
#  'tulemus',
#  'ole',
#  'mina',
#  'kott',
#  ':',
#  'tutt',
#  'uus',
#  'juhe',
#  'hiir',
#  'Logitech',
#  'LX7',
#  '(',
#  'awwww',
#  ')',
#  'ning',
#  'sama',
#  'asutus',
#  'kõrva',
#  'klapp',
#  '.',
#  'maksi',
#  'oma',
#  'jagu',
#  'aga',
#  'nagu',
#  'tead',
#  'siis',
#  'raha',
#  'ole',
#  'mina',
#  'jaoks',
#  'kõigest',
#  'number',
#  'panga',
#  'konto',
#  '.',
#  'SGA',
#  'uus',
#  'hoo',
#  'aeg',
#  'alga',
#  '.',
#  'ole',
#  'päris',
#  'BSG',
#  'aga',
#  'täiesti',
#  'vaatatav',
#  '.',
#  'Amanda',
#  'Tapping',
#  'isegi',
#  'löö',
#  'uus',
#  'hoo',
#  'aeg',
#  'kaasa',
#  '.',
#  'Õmmm',
#  'NV',
#  'alga',
#  '...',
#  '(',
#  'ole',
#  'lihtsalt',
#  'miski',
#  'siia',
#  'rohkem',
#  'kirjuta',
#  ')',
#  'seega',
#  'rõhuta',
#  'veel',
#  'kord',
#  'täna',
#  'ole',
#  'hea',
#  'päev',
#  '.',
#  'mina',
#  'tead',
#  ',',
#  'et',
#  'materiaalne',
#  'väärtus',
#  'tege',
#  'mina',
#  'õnnelik',
#  ',',
#  'kuigi',
#  'see',
#  'jaoks',
#  'pida',
#  'ole',
#  'muu',
#  'viis',
#  'ja',
#  'moodus',
#  '.',
#  'aga',
#  'see',
#  'teine',
#  'kord',
#  '.',
#  'jõud',
#  'siis',
#  'täna',
#  'töö',
#  'normaal',
#  'aeg',
#  'kodu',
#  'ja',
#  'nagu',
#  'esimene',
#  'asi',
#  'peale',
#  'uks',
#  'avamine',
#  'ning',
#  'viisu',
#  'eemaldamine',
#  'jalg',
#  'lükka',
#  'rüpe',
#  'raal',
#  'töö',
#  '.',
#  'arvuti',
#  'stard',
#  'avane',
#  'ka',
#  'MSN',
#  'sõnumi',
#  'tooja',
#  '(',
#  'tm',
#  ')',
#  'aken',
#  'ning',
#  'logi',
#  'sisse',
#  '.',
#  'Vat',
#  'siit',
#  'tule',
#  'püänt',
#  '.',
#  'mina',
#  'logi',
#  'MSN',
#  'sisse',
#  'aga',
#  'ei',
#  'olnud',
#  'seal',
#  'chat',
#  'ready',
#  '(',
#  'mr',
#  'Arvin',
#  'Nugis',
#  'ütle',
#  ',',
#  'et',
#  'talk',
#  'later',
#  ')',
#  'kuna',
#  'mina',
#  'maine',
#  'hing',
#  'ole',
#  'eemal',
#  '.',
#  'tekki',
#  'küsimus',
#  ',',
#  'et',
#  'WTF',
#  '?',
#  'mina',
#  'üldse',
#  'siis',
#  'online',
#  'mine',
#  '?',
#  'nii',
#  'nüüd',
#  'saa',
#  'peale',
#  'väike',
#  'vahea',
#  'jälle',
#  'blogi',
#  'ja',
#  'enamik',
#  'mõte',
#  ',',
#  'mis',
#  'taht',
#  'lärmakalt',
#  'kuulu',
#  'saa',
#  'kiri',
#  'pandud',
#  '.',
#  'mõni',
#  'lause',
#  'jää',
#  'kiri',
#  'pane',
#  ',',
#  'kuna',
#  'rongi',
#  'sõit',
#  'ole',
#  'lühike',
#  'ja',
#  'ei',
#  'jõud',
#  'klaver',
#  'piisavalt',
#  'kiirelt',
#  'kuluta',
#  '.',
#  'tegelikult',
#  'ole',
#  'ilge',
#  'isu',
#  'whin',
#  'see',
#  'üle',
#  ',',
#  'et',
#  'miks',
#  'mina',
#  'girlfriend',
#  'ole',
#  'kes',
#  'tsilli',
#  'ja',
#  'värk',
#  'või',
#  'siis',
#  'tema',
#  'aga',
#  'noh',
#  'useless',
#  'stuff',
#  '.',
#  'vait',
#  'ole',
#  'ja',
#  'edasi',
#  'teeni']

# %%
oletamisega.root_tokens[20]
# Out:
# [['järele', 'andmatult']]

# %%
oletamisega.root_tokens[12]
# Out:
# 2
