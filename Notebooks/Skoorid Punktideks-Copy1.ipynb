# %%
import os
import json

# %% [markdown]
# Formaalsus

# %%
def formaalsus(andmed):
    
    skoor0 = 0
    skoor1 = 0
    skoor2 = 0
    
    skoor_temp = 0
    
    tunnus_TTR = andmed["TTR"]
    # Kui tunnust tekstis ei leidunud, ei mõjuta see skoori
    if tunnus_TTR == -1:
        skoor_temp += 0
    # Jagasin polaarse tunnuse korpuse alusel 11-ks võrdseks osaks, et hinnata
    # <= 9.1%
    elif tunnus_TTR <= 0.450412:
        skoor_temp -= 5
    # <= 18.2%
    elif tunnus_TTR <= 0.520466:
        skoor_temp -= 4
    # <= 27.3%
    elif tunnus_TTR <= 0.571429:
        skoor_temp -= 3
    # <= 36.3%
    elif tunnus_TTR <= 0.611948:
        skoor_temp -= 2
    # <= 45.4%
    elif tunnus_TTR <= 0.647191:
        skoor_temp -= 1
    # <= 54.5%
    elif tunnus_TTR <= 0.679739:
        skoor_temp += 0
    # <= 63.6%
    elif tunnus_TTR <= 0.709795:
        skoor_temp += 1
    # <= 72.7%
    elif tunnus_TTR <= 0.740260:
        skoor_temp += 2
    # <= 81.8%
    elif tunnus_TTR <= 0.772973:
        skoor_temp += 3
    # <= 90.9%
    elif tunnus_TTR <= 0.813333:
        skoor_temp += 4
    # <= 100% (ka suuremad, kui korpuses leiduvad)
    else:
        skoor_temp += 5
    
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 9.06
    skoor2 += skoor_temp * 4.83
    skoor_temp = 0
    
    tunnus_a1i = andmed["asesõnade_esimese_isiku_osaarv"]
    # Kui tunnust tekstis ei leidunud, ei mõjuta see skoori
    if tunnus_a1i == -1:
        skoor_temp -= 0
    # Jagasin mitte-polaarse tunnuse korpuse alusel 6-ks võrdseks osaks, et hinnata
    # <= 16.7%
    elif tunnus_a1i <= 0.000000:
        skoor_temp -= 0
    # <= 33.3%
    elif tunnus_a1i <= 0.242424:
        skoor_temp -= 1
    # <= 50%
    elif tunnus_a1i <= 0.500000:
        skoor_temp -= 2
    # <= 66.7%
    elif tunnus_a1i <= 0.666667:
        skoor_temp -= 3
    # <= 83.3%
    elif tunnus_a1i <= 0.894737:
        skoor_temp -= 4
    # <= 100% (ka suuremad, kui korpuses leiduvad)
    else:
        skoor_temp -= 5
    
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 8.08
    skoor2 += skoor_temp * 4.45
    skoor_temp = 0
    
    tunnus_a2i = andmed["asesõnade_teise_isiku_osaarv"]
    # Kui tunnust tekstis ei leidunud, ei mõjuta see skoori
    if tunnus_a2i == -1:
        skoor_temp -= 0
    # Jagasin mitte-polaarse tunnuse korpuse alusel 6-ks võrdseks osaks, et hinnata
    # <= 50%
    elif tunnus_a2i == 0.000000:
        skoor_temp -= 0
    # <= 66.7%
    elif tunnus_a2i <= 0.200000:
        skoor_temp -= 3
    # <= 83.3%
    elif tunnus_a2i <= 0.500000:
        skoor_temp -= 4
    # <= 100% (ka suuremad, kui korpuses leiduvad)
    else:
        skoor_temp -= 5
    
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 6.63
    skoor2 += skoor_temp * 3.86
    skoor_temp = 0
    
    tunnus_v1i = andmed["verbide_esimese_isiku_osaarv"]
    # Kui tunnust tekstis ei leidunud, ei mõjuta see skoori
    if tunnus_v1i == -1:
        skoor_temp -= 0
    # Jagasin mitte-polaarse tunnuse korpuse alusel 6-ks võrdseks osaks, et hinnata
    # <= 33.3%
    elif tunnus_v1i == 0.000000:
        skoor_temp -= 0
    # <= 50%
    elif tunnus_v1i <= 0.105263:
        skoor_temp -= 2
    # <= 66.7%
    elif tunnus_v1i <= 0.222222:
        skoor_temp -= 3
    # <= 83.3%
    elif tunnus_v1i <= 0.375000:
        skoor_temp -= 4
    # <= 100% (ka suuremad, kui korpuses leiduvad)
    else:
        skoor_temp -= 5
    
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 12.40
    skoor2 += skoor_temp * 6.04
    skoor_temp = 0
    
    tunnus_v2i = andmed["verbide_teise_isiku_osaarv"]
    # Kui tunnust tekstis ei leidunud, ei mõjuta see skoori
    if tunnus_v2i == -1:
        skoor_temp -= 0
    # Jagasin mitte-polaarse tunnuse korpuse alusel 6-ks võrdseks osaks, et hinnata
    # <= 16.7%
    elif tunnus_v2i <= 0.000000:
        skoor_temp -= 0
    # <= 33.3%
    elif tunnus_v2i <= 0.058824:
        skoor_temp -= 1
    # <= 50%
    elif tunnus_v2i <= 0.125000:
        skoor_temp -= 2
    # <= 66.7%
    elif tunnus_v2i <= 0.200000:
        skoor_temp -= 3
    # <= 83.3%
    elif tunnus_v2i <= 0.333333:
        skoor_temp -= 4
    # <= 100% (ka suuremad, kui korpuses leiduvad)
    else:
        skoor_temp -= 5
    
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 4.88
    skoor2 += skoor_temp * 3.10
    skoor_temp = 0
    
    tunnus_a3i = andmed["asesõnade_kolmanda_isiku_osaarv"]
    # Kui tunnust tekstis ei leidunud, ei mõjuta see skoori
    if tunnus_a3i == -1:
        skoor_temp += 0
    # Jagasin mitte-polaarse tunnuse korpuse alusel 6-ks võrdseks osaks, et hinnata
    # <= 33.3%
    elif tunnus_a3i == 0.000000:
        skoor_temp += 0
    # <= 50%
    elif tunnus_a3i <= 0.200000:
        skoor_temp += 2
    # <= 66.7%
    elif tunnus_a3i <= 0.416667:
        skoor_temp += 3
    # <= 83.3%
    elif tunnus_a3i <= 0.800000:
        skoor_temp += 4
    # <= 100% (ka suuremad, kui korpuses leiduvad)
    else:
        skoor_temp += 5
    
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 2.28
    skoor2 += skoor_temp * 1.80
    skoor_temp = 0
    
    tunnus_v3i = andmed["verbide_kolmanda_isiku_osaarv"]
    # Kui tunnust tekstis ei leidunud, ei mõjuta see skoori
    if tunnus_v3i == -1:
        skoor_temp += 0
    # Jagasin mitte-polaarse tunnuse korpuse alusel 6-ks võrdseks osaks, et hinnata
    # <= 16.7%
    elif tunnus_v3i <= 0.400000:
        skoor_temp += 0
    # <= 33.3%
    elif tunnus_v3i <= 0.536585:
        skoor_temp += 1
    # <= 50%
    elif tunnus_v3i <= 0.666667:
        skoor_temp += 2
    # <= 66.7%
    elif tunnus_v3i <= 0.800000:
        skoor_temp += 3
    # <= 83.3%
    elif tunnus_v3i <= 0.945946:
        skoor_temp += 4
    # <= 100% (ka suuremad, kui korpuses leiduvad)
    else:
        skoor_temp += 5
    
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 13.47
    skoor2 += skoor_temp * 6.41
    skoor_temp = 0
    
    tunnus_emotikonide_arv = andmed["emotikonide_arv"]
    # Binaarse tunnuse (on või ei ole) skoor_temp on vastavalt kas 5 või 0
    if tunnus_emotikonide_arv > 0.0000:
        skoor_temp -= 5
    
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 9.80
    skoor2 += skoor_temp * 5.11
    skoor_temp = 0
    
    tunnus_kaudse_kõneviisi_osakaal = andmed["kaudse_kõneviisi_osakaal"]
    # Binaarse tunnuse (on või ei ole) skoor_temp on vastavalt kas 5 või 0
    if tunnus_kaudse_kõneviisi_osakaal > 0.0000:
        skoor_temp += 5
    
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 0.12
    skoor2 += skoor_temp * 0.22
    skoor_temp = 0
    
    tunnus_nud = andmed["nud-partitsiibiga_verbide_osakaal"]
        # Kui tunnust tekstis ei leidunud, ei mõjuta see skoori
    if tunnus_nud == -1:
        skoor_temp -= 0
    # Jagasin mitte-polaarse tunnuse korpuse alusel 6-ks võrdseks osaks, et hinnata
    # <= 16.7%
    elif tunnus_nud == 0.000000:
        skoor_temp -= 0
    # <= 33.3%
    elif tunnus_nud <= 0.011429:
        skoor_temp -= 1
    # <= 50%
    elif tunnus_nud <= 0.031250:
        skoor_temp -= 2
    # <= 66.7%
    elif tunnus_nud <= 0.049180:
        skoor_temp -= 3
    # <= 83.3%
    elif tunnus_nud <= 0.073529:
        skoor_temp -= 4
    # <= 100% (ka suuremad, kui korpuses leiduvad)
    else:
        skoor_temp -= 5
    
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 1.66
    skoor2 += skoor_temp * 1.44
    skoor_temp = 0
    
    tunnus_passiiv = andmed["passiivi_osakaal"]
    # Kui tunnust tekstis ei leidunud, ei mõjuta see skoori
    if tunnus_passiiv == -1:
        skoor_temp += 0
    # Jagasin mitte-polaarse tunnuse korpuse alusel 6-ks võrdseks osaks, et hinnata
    # <= 16.7%
    elif tunnus_passiiv <= 0.019608:
        skoor_temp += 0
    # <= 33.3%
    elif tunnus_passiiv <= 0.043011:
        skoor_temp += 1
    # <= 50%
    elif tunnus_passiiv <= 0.065246:
        skoor_temp += 2
    # <= 66.7%
    elif tunnus_passiiv <= 0.095808:
        skoor_temp += 3
    # <= 83.3%
    elif tunnus_passiiv <= 0.148138:
        skoor_temp += 4
    # <= 100% (ka suuremad, kui korpuses leiduvad)
    else:
        skoor_temp += 5
    
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 10.93
    skoor2 += skoor_temp * 5.52
    skoor_temp = 0
    
    tunnus_käändsõnad = andmed["käändsõnade_osaarv"]
    # Kui tunnust tekstis ei leidunud, ei mõjuta see skoori
    if tunnus_käändsõnad == -1:
        skoor_temp += 0
    # Jagasin polaarse tunnuse korpuse alusel 11-ks võrdseks osaks, et hinnata
    # <= 9.1%
    elif tunnus_käändsõnad <= 0.333333:
        skoor_temp -= 5
    # <= 18.2%
    elif tunnus_käändsõnad <= 0.378481:
        skoor_temp -= 4
    # <= 27.3%
    elif tunnus_käändsõnad <= 0.415044:
        skoor_temp -= 3
    # <= 36.4%
    elif tunnus_käändsõnad <= 0.447115:
        skoor_temp -= 2
    # <= 45.5%
    elif tunnus_käändsõnad <= 0.475958:
        skoor_temp -= 1
    # <= 54.5%
    elif tunnus_käändsõnad <= 0.502941:
        skoor_temp += 0
    # <= 63.6%
    elif tunnus_käändsõnad <= 0.527778:
        skoor_temp += 1
    # <= 72.7%
    elif tunnus_käändsõnad <= 0.552941:
        skoor_temp += 2
    # <= 81.8%
    elif tunnus_käändsõnad <= 0.581395:
        skoor_temp += 3
    # <= 90.9%
    elif tunnus_käändsõnad <= 0.619570:
        skoor_temp += 4
    # <= 100% (ka suuremad, kui korpuses leiduvad)
    else:
        skoor_temp += 5
    
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 22.81
    skoor2 += skoor_temp * 9.33
    skoor_temp = 0
    
    tunnus_lemmapikkus = andmed["lemmapikkuse_osaarv"]
    # Kui tunnust tekstis ei leidunud, ei mõjuta see skoori
    if tunnus_lemmapikkus == -1:
        skoor_temp += 0
    # Jagasin polaarse tunnuse korpuse alusel 11-ks võrdseks osaks, et hinnata
    # <= 9.1%
    elif tunnus_lemmapikkus <= 4.401786:
        skoor_temp -= 5
    # <= 18.2%
    elif tunnus_lemmapikkus <= 4.543703:
        skoor_temp -= 4
    # <= 27.3%
    elif tunnus_lemmapikkus <= 4.657800:
        skoor_temp -= 3
    # <= 36.4%
    elif tunnus_lemmapikkus <= 4.760417:
        skoor_temp -= 2
    # <= 45.5%
    elif tunnus_lemmapikkus <= 4.854926:
        skoor_temp -= 1
    # <= 54.5%
    elif tunnus_lemmapikkus <= 4.949524:
        skoor_temp += 0
    # <= 63.6%
    elif tunnus_lemmapikkus <= 5.045977:
        skoor_temp += 1
    # <= 72.7%
    elif tunnus_lemmapikkus <= 5.153620:
        skoor_temp += 2
    # <= 81.8%
    elif tunnus_lemmapikkus <= 5.282090:
        skoor_temp += 3
    # <= 90.9%
    elif tunnus_lemmapikkus <= 5.468645:
        skoor_temp += 4
    # <= 100% (ka suuremad, kui korpuses leiduvad)
    else:
        skoor_temp += 5
    
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 17.86
    skoor2 += skoor_temp * 7.84
    skoor_temp = 0
    
    tunnus_leksikon = andmed["leksikonides_esinevade_osaarv"]
    # Kui tunnust tekstis ei leidunud, ei mõjuta see skoori
    if tunnus_leksikon == -1:
        skoor_temp -= 0
    # Jagasin mitte-polaarse tunnuse korpuse alusel 6-ks võrdseks osaks, et hinnata
    # <= 16.7%
    elif tunnus_leksikon <= 0.000083:
        skoor_temp -= 0
    # <= 33.3%
    elif tunnus_leksikon <= 0.001855:
        skoor_temp -= 1
    # <= 50%
    elif tunnus_leksikon <= 0.003195:
        skoor_temp -= 2
    # <= 66.7%
    elif tunnus_leksikon <= 0.004831:
        skoor_temp -= 3
    # <= 83.3%
    elif tunnus_leksikon <= 0.007143:
        skoor_temp -= 4
    # <= 100% (ka suuremad, kui korpuses leiduvad)
    else:
        skoor_temp -= 5
        
    
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 5.53
    skoor2 += skoor_temp * 3.39
    skoor_temp = 0
    
    # Väljastab ühtlustamata skoori, et nende alusel arvutada uued skoorid
    return (skoor0, skoor1, skoor2)

# %% [markdown]
# Spontaansus

# %%
def spontaansus(andmed):
    
    skoor0 = 0
    skoor1 = 0
    skoor2 = 0
    
    skoor_temp = 0
    
    tunnus_TTR = andmed["TTR"]
    # Kui tunnust tekstis ei leidunud, ei mõjuta see skoori
    if tunnus_TTR == -1:
        skoor_temp += 0
    # Jagasin polaarse tunnuse korpuse alusel 11-ks võrdseks osaks, et hinnata
    # <= 9.1%
    elif tunnus_TTR <= 0.450412:
        skoor_temp += 5
    # <= 18.2%
    elif tunnus_TTR <= 0.520466:
        skoor_temp += 4
    # <= 27.3%
    elif tunnus_TTR <= 0.571429:
        skoor_temp += 3
    # <= 36.3%
    elif tunnus_TTR <= 0.611948:
        skoor_temp += 2
    # <= 45.4%
    elif tunnus_TTR <= 0.647191:
        skoor_temp += 1
    # <= 54.5%
    elif tunnus_TTR <= 0.679739:
        skoor_temp += 0
    # <= 63.6%
    elif tunnus_TTR <= 0.709795:
        skoor_temp -= 1
    # <= 72.7%
    elif tunnus_TTR <= 0.740260:
        skoor_temp -= 2
    # <= 81.8%
    elif tunnus_TTR <= 0.772973:
        skoor_temp -= 3
    # <= 90.9%
    elif tunnus_TTR <= 0.813333:
        skoor_temp -= 4
    # <= 100% (ka suuremad, kui korpuses leiduvad)
    else:
        skoor_temp -= 5
        
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 6.94
    skoor2 += skoor_temp * 3.99
    skoor_temp = 0
    
    tunnus_emotikonide_arv = andmed["emotikonide_arv"]
    # Binaarse tunnuse (on või ei ole) skoor_temp on vastavalt kas 5 või 0
    if tunnus_emotikonide_arv > 0.0000:
        skoor_temp += 5
        
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 8.06
    skoor2 += skoor_temp * 4.44
    skoor_temp = 0
    
    tunnus_lemmapikkus = andmed["lemmapikkuse_osaarv"]
    # Kui tunnust tekstis ei leidunud, ei mõjuta see skoori
    if tunnus_lemmapikkus == -1:
        skoor_temp += 0
    # Jagasin polaarse tunnuse korpuse alusel 11-ks võrdseks osaks, et hinnata
    # <= 9.1%
    elif tunnus_lemmapikkus <= 4.401786:
        skoor_temp += 5
    # <= 18.2%
    elif tunnus_lemmapikkus <= 4.543703:
        skoor_temp += 4
    # <= 27.3%
    elif tunnus_lemmapikkus <= 4.657800:
        skoor_temp += 3
    # <= 36.4%
    elif tunnus_lemmapikkus <= 4.760417:
        skoor_temp += 2
    # <= 45.5%
    elif tunnus_lemmapikkus <= 4.854926:
        skoor_temp += 1
    # <= 54.5%
    elif tunnus_lemmapikkus <= 4.949524:
        skoor_temp += 0
    # <= 63.6%
    elif tunnus_lemmapikkus <= 5.045977:
        skoor_temp -= 1
    # <= 72.7%
    elif tunnus_lemmapikkus <= 5.153620:
        skoor_temp -= 2
    # <= 81.8%
    elif tunnus_lemmapikkus <= 5.282090:
        skoor_temp -= 3
    # <= 90.9%
    elif tunnus_lemmapikkus <= 5.468645:
        skoor_temp -= 4
    # <= 100% (ka suuremad, kui korpuses leiduvad)
    else:
        skoor_temp -= 5
        
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 13.20
    skoor2 += skoor_temp * 6.32
    skoor_temp = 0
    
    tunnus_tajuverbide_osaarv = andmed["tajuverbide_osaarv"]
    # Kui tunnust tekstis ei leidunud, ei mõjuta see skoori
    if tunnus_tajuverbide_osaarv == -1:
        skoor_temp += 0
    # Jagasin mitte-polaarse tunnuse korpuse alusel 6-ks võrdseks osaks, et hinnata
    # <= 16.7%
    elif tunnus_tajuverbide_osaarv <= 0.044118:
        skoor_temp += 0
    # <= 33.3%
    elif tunnus_tajuverbide_osaarv <= 0.085714:
        skoor_temp += 1
    # <= 50%
    elif tunnus_tajuverbide_osaarv <= 0.117647:
        skoor_temp += 2
    # <= 66.7%
    elif tunnus_tajuverbide_osaarv <= 0.150000:
        skoor_temp += 3
    # <= 83.3%
    elif tunnus_tajuverbide_osaarv <= 0.192652:
        skoor_temp += 4
    # <= 100% (ka suuremad, kui korpuses leiduvad)
    else:
        skoor_temp += 5
        
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 2.01
    skoor2 += skoor_temp * 1.65
    skoor_temp = 0
    
    tunnus_kokkukleepunud_kirjavahemärkide_arv = andmed["kokkukleepunud_kirjavahemärkide_arv"]
    # Binaarse tunnuse (on või ei ole) skoor_temp on vastavalt kas 5 või 0
    if tunnus_kokkukleepunud_kirjavahemärkide_arv > 0.0000:
        skoor_temp += 5
        
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 10.17
    skoor2 += skoor_temp * 5.24
    skoor_temp = 0
    
    tunnus_korduvate_juppide_arv = andmed["korduvate_juppide_arv"]
    # Binaarse tunnuse (on või ei ole) skoor_temp on vastavalt kas 5 või 0
    if tunnus_korduvate_juppide_arv > 0.0000:
        skoor_temp += 5
        
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 1.57
    skoor2 += skoor_temp * 1.38
    skoor_temp = 0
    
    tunnus_läbinisti_suur = andmed["läbinisti_suur"]
    # Kui tunnust tekstis ei leidunud, ei mõjuta see skoori
    if tunnus_läbinisti_suur == -1:
        skoor_temp += 0
    # Jagasin mitte-polaarse tunnuse korpuse alusel 6-ks võrdseks osaks, et hinnata
    # Ei käsitle kirjavigasid binaarsetena, kuna neid võib olla vale-positiivseid (nt pärisnimesid)
    # <= 16.7%
    elif tunnus_läbinisti_suur == 0.000000:
        skoor_temp += 0
    # <= 66.7%
    elif tunnus_läbinisti_suur <= 0.002037:
        skoor_temp += 3
    # <= 83.3%
    elif tunnus_läbinisti_suur <= 0.009217:
        skoor_temp += 4
    # <= 100% (ka suuremad, kui korpuses leiduvad)
    else:
        skoor_temp += 5
        
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 7.03
    skoor2 += skoor_temp * 4.03
    skoor_temp = 0
    
    tunnus_puuduva_suure_algustähega = andmed["puuduva_suure_algustähega"]
    # Binaarse tunnuse (on või ei ole) skoor_temp on vastavalt kas 5 või 0
    if tunnus_puuduva_suure_algustähega > 0.0000:
        skoor_temp += 5
        
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 11.25
    skoor2 += skoor_temp * 5.63
    skoor_temp = 0
    
    tunnus_a1i = andmed["asesõnade_esimese_isiku_osaarv"]
    # Kui tunnust tekstis ei leidunud, ei mõjuta see skoori
    if tunnus_a1i == -1:
        skoor_temp += 0
    # Jagasin mitte-polaarse tunnuse korpuse alusel 6-ks võrdseks osaks, et hinnata
    # <= 16.7%
    elif tunnus_a1i <= 0.000000:
        skoor_temp += 0
    # <= 33.3%
    elif tunnus_a1i <= 0.242424:
        skoor_temp += 1
    # <= 50%
    elif tunnus_a1i <= 0.500000:
        skoor_temp += 2
    # <= 66.7%
    elif tunnus_a1i <= 0.666667:
        skoor_temp += 3
    # <= 83.3%
    elif tunnus_a1i <= 0.894737:
        skoor_temp += 4
    # <= 100% (ka suuremad, kui korpuses leiduvad)
    else:
        skoor_temp += 5
        
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 3.74
    skoor2 += skoor_temp * 2.57
    skoor_temp = 0
    
    tunnus_leksikon = andmed["leksikonides_esinevade_osaarv"]
    # Kui tunnust tekstis ei leidunud, ei mõjuta see skoori
    if tunnus_leksikon == -1:
        skoor_temp += 0
    # Jagasin mitte-polaarse tunnuse korpuse alusel 6-ks võrdseks osaks, et hinnata
    # <= 16.7%
    elif tunnus_leksikon <= 0.000083:
        skoor_temp += 0
    # <= 33.3%
    elif tunnus_leksikon <= 0.001855:
        skoor_temp += 1
    # <= 50%
    elif tunnus_leksikon <= 0.003195:
        skoor_temp += 2
    # <= 66.7%
    elif tunnus_leksikon <= 0.004831:
        skoor_temp += 3
    # <= 83.3%
    elif tunnus_leksikon <= 0.007143:
        skoor_temp += 4
    # <= 100% (ka suuremad, kui korpuses leiduvad)
    else:
        skoor_temp += 5
        
    skoor0 += skoor_temp
    skoor1 += skoor_temp * 7.74
    skoor2 += skoor_temp * 4.31
    skoor_temp = 0
    
    # Väljastab ühtlustamata skoori, et nende alusel arvutada uued skoorid
    return (skoor0, skoor1, skoor2)

# %% [markdown]
# Skooride failid

# %%
def teisenda_vahemikku(algne, maksimum, miinimum):
    uus = ((algne - miinimum) / (maksimum - miinimum))
    
    if uus > 1:
        return 1.0
    elif uus < 0:
        return 0.0
    else:
        return uus

# %%
# Algse kausta nimi, võtab sealt algsed failinimed, ei loe neid faile sisse
source = "../etnc19_web_2019_andmed/"
target = "../etnc19_web_2019_skoorid/"

os.makedirs(os.path.dirname(target), exist_ok=True)

# Avab järjest kõik failid algkaustas
for file in [f for f in os.listdir(source)]:
    
    source_filename = os.path.join(source, file)
    with open(source_filename, "r", encoding="UTF-8") as fr:
        andmed = json.load(fr)
    
    skoorid = dict()
    
    formaalsus_ilma, formaalsus_kaalud, formaalsus_kaalud_sujuv = formaalsus(andmed)
    
    skoorid["formaalsus_kaalud_sujuv"] = teisenda_vahemikku(formaalsus_kaalud_sujuv, 178, -221)
    skoorid["formaalsus_kaalud"] = teisenda_vahemikku(formaalsus_kaalud, 382, -445)
    skoorid["formaalsus_ilma"] = teisenda_vahemikku(formaalsus_ilma, 34, -44)
    
    spontaansus_ilma, spontaansus_kaalud, spontaansus_kaalud_sujuv = spontaansus(andmed)
    
    skoorid["spontaansus_kaalud_sujuv"] = teisenda_vahemikku(spontaansus_kaalud_sujuv, 196, -51)
    skoorid["spontaansus_kaalud"] = teisenda_vahemikku(spontaansus_kaalud, 356, -100)
    skoorid["spontaansus_ilma"] = teisenda_vahemikku(spontaansus_ilma, 49, -10)
    
    target_filename = os.path.join(target, file)
    
    with open(target_filename, "w", encoding="UTF-8") as fw:
        json.dump(skoorid, fw, sort_keys=True, indent=4)

# %% [markdown]
# Piiride arvutamine

# %%
form_ilma = []
form_kaalud = []
form_sujuv = []

spon_ilma = []
spon_kaalud = []
spon_sujuv = []

for file in [f for f in os.listdir(source)]:
    source_filename = os.path.join(source, file)
    with open(source_filename, "r", encoding="UTF-8") as fr:
        andmed = json.load(fr)
        
    skoorid = dict()
    formaalsus_ilma, formaalsus_kaalud, formaalsus_kaalud_sujuv = formaalsus(andmed)
    
    form_ilma.append(formaalsus_ilma)
    form_kaalud.append(formaalsus_kaalud)
    form_sujuv.append(formaalsus_kaalud_sujuv)
    
    spontaansus_ilma, spontaansus_kaalud, spontaansus_kaalud_sujuv = spontaansus(andmed)
    
    spon_ilma.append(spontaansus_ilma)
    spon_kaalud.append(spontaansus_kaalud)
    spon_sujuv.append(spontaansus_kaalud_sujuv)

# %%
for loend in (form_ilma, form_kaalud, form_sujuv):
    print(max(loend))
    print(min(loend))
    print()
# Out:
# 34
# -45
#
# 382.05
# -445.86999999999995
#
# 178.64999999999998
# -221.96999999999997

# %%
for loend in (spon_ilma, spon_kaalud, spon_sujuv):
    print(max(loend))
    print(min(loend))
    print()
# Out:
# 49
# -10
#
# 356.53999999999996
# -100.7
#
# 196.14999999999998
# -51.550000000000004

# %% [markdown]
# Minikorpuse arvutamine

# %%
# Algse kausta nimi, võtab sealt algsed failinimed, ei loe neid faile sisse
sources = ["../minikorpus/mini_andmed", "../minikorpus/lisa_andmed"]
target = "../minikorpus/skoorid_koos/"

os.makedirs(os.path.dirname(target), exist_ok=True)

for source in sources:
    # Avab järjest kõik failid algkaustas
    for file in [f for f in os.listdir(source)]:

        source_filename = os.path.join(source, file)
        with open(source_filename, "r", encoding="UTF-8") as fr:
            andmed = json.load(fr)

        skoorid = dict()

        formaalsus_ilma, formaalsus_kaalud, formaalsus_kaalud_sujuv = formaalsus(andmed)

        skoorid["formaalsus_kaalud_sujuv"] = teisenda_vahemikku(formaalsus_kaalud_sujuv, 178, -221)
        skoorid["formaalsus_kaalud"] = teisenda_vahemikku(formaalsus_kaalud, 382, -445)
        skoorid["formaalsus_ilma"] = teisenda_vahemikku(formaalsus_ilma, 34, -44)

        spontaansus_ilma, spontaansus_kaalud, spontaansus_kaalud_sujuv = spontaansus(andmed)

        skoorid["spontaansus_kaalud_sujuv"] = teisenda_vahemikku(spontaansus_kaalud_sujuv, 196, -51)
        skoorid["spontaansus_kaalud"] = teisenda_vahemikku(spontaansus_kaalud, 356, -100)
        skoorid["spontaansus_ilma"] = teisenda_vahemikku(spontaansus_ilma, 49, -10)

        target_filename = os.path.join(target, file)

        with open(target_filename, "w", encoding="UTF-8") as fw:
            json.dump(skoorid, fw, sort_keys=True, indent=4)

# %%
import pandas as pd

# %%
target = "../minikorpus/skoorid_koos_vahed/"
source = "../minikorpus/skoorid_koos/"

os.makedirs(os.path.dirname(target), exist_ok=True)

df = pd.read_csv('../minikorpus/Randmestik.csv')

# %%
df.rename(columns={'Unnamed: 0': 'failinimi'}, inplace = True)

# %%
from collections import defaultdict

# %%
skooristik = defaultdict(lambda: 0)

for filename, form, spon in zip(df['failinimi'], df['formaalsus'], df['spontaansus']):
    skoornimi = filename.split(".txt")[0] + "_andmed.json"
    
    source_filename = os.path.join(source, file)
    with open(source_filename, "r", encoding="UTF-8") as fr:
        skoorid = json.load(fr)
        
    skooristik["arv"] += 1
     
    skooristik["formaalsus_ilma"] += skoorid["formaalsus_ilma"] - form
    skooristik["formaalsus_kaalud"] += skoorid["formaalsus_kaalud"] - form
    skooristik["formaalsus_kaalud_sujuv"] += skoorid["formaalsus_kaalud_sujuv"] - form
        
    skooristik["spontaansus_ilma"] += skoorid["spontaansus_ilma"] - spon
    skooristik["spontaansus_kaalud"] += skoorid["spontaansus_kaalud"] - spon
    skooristik["spontaansus_kaalud_sujuv"] += skoorid["spontaansus_kaalud_sujuv"] - spon
    
skooristik["formaalsus_ilma"] /= skooristik["arv"]
skooristik["formaalsus_kaalud"] /= skooristik["arv"]
skooristik["formaalsus_kaalud_sujuv"] /= skooristik["arv"]

skooristik["spontaansus_ilma"] /= skooristik["arv"]
skooristik["spontaansus_kaalud"] /= skooristik["arv"]
skooristik["spontaansus_kaalud_sujuv"] /= skooristik["arv"]

with open("../minikorpus/keskmine_erinevus_inimhinnanguga.json", "w", encoding="UTF-8") as fw:
    json.dump(skooristik, fw, sort_keys=True, indent=4)
